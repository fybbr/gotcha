# %% [markdown]
# # FIX Delta Times
# ## NewOrderSingle to ExecutionReport (NEW)

# %% [markdown]
# \date{October 31, 2014}

# %%
# %run FIXdaygroup.py
# Out:
# *** Processing logfile ..\logs3\FIX.4.4-E2MUS-SGNUS.messages.current.log ...
