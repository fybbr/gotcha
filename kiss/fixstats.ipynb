# %%
import plotstats
# %matplotlib inline

# %pylab inline
pylab.rcParams['figure.figsize'] = (12, 6)

x = plotstats.plot('FIXstatsUS_20016-09-09.pkl','US FIX Stats')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1083f3b5b421> in <module>
#       5 pylab.rcParams['figure.figsize'] = (12, 6)
#       6
# ----> 7 x = plotstats.plot('FIXstatsUS_20016-09-09.pkl','US FIX Stats')
#
# ~\Documents\projetcs\gotcha\kiss\plotstats.py in plot(file_name, chart_title)
#      28
#      29     # Plot
# ---> 30     p1 = sdf.plot(x=pd.to_datetime(sdf.date), y=['min', '25%', '75%', 'mean'], title=chart_title)
#      31     p1.set_ylabel('ms')
#      32
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
# ...

# %%
y = plotstats.plot('FIXstatsBOV_20016-09-09.pkl','BOVESPAF FIX Stats')

# %%
a = plotstats.plot('FIXstats.pkl','XP Stats')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f4e00ac18ef3> in <module>
# ----> 1 a = plotstats.plot('FIXstats.pkl','XP Stats')
#
# ~\Documents\projetcs\gotcha\kiss\plotstats.py in plot(file_name, chart_title)
#      17
#      18     # Remove outliers
# ---> 19     sdf = sdf[np.abs(sdf['mean'] - sdf['mean'].mean()) <= (2 * sdf['mean'].std())]
#      20
#      21     # Convert to timedelta64
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   11638             )
#   11639         return self._reduce(
# > 11640             f, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   11641         )
#   11642
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
# ...

# %%
z = plotstats.plot('FIXstatsBMF_20016-09-09.pkl','BM&F FIX Stats')
